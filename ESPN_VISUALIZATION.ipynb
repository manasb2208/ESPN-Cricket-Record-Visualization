# %%
import seaborn as sns
import pandas as pd

# %%
mens_odi = pd.read_csv("/content/ICC ODI Championship.csv")
mens_odi
# Out:
#     Pos          Team  Matches  Points  Rating
# 0     1       England       44    5405     123
# 1     2         India       52    6102     117
# 2     3   New Zealand       32    3716     116
# 3     4     Australia       39    4344     111
# 4     5  South Africa       31    3345     108
# 5     6      Pakistan       35    3490     100
# 6     7    Bangladesh       34    2989      88
# 7     8     Sri Lanka       39    3297      85
# 8     9   West Indies       43    3285      76
# 9    10   Afghanistan       28    1549      55
# 10   11       Ireland       24    1256      52
# 11   12   Netherlands        5     222      44
# 12   13      Zimbabwe       27    1121      42
# 13   14          Oman       12     479      40
# 14   15      Scotland       16     419      26
# 15   16         Nepal        9     161      18
# 16   17           UAE       15     259      17
# 17   18       Namibia        9     152      17
# 18   19           USA       14     185      13
# ...

# %%
mens_test = pd.read_csv("/content/ICC Test Championship.csv")
mens_test
# Out:
#     Pos          Team  Matches  Points  Rating
# 0     1     Australia       26    3028     116
# 1     2   New Zealand       21    2406     115
# 2     3         India       27    3085     114
# 3     4       England       41    4326     106
# 4     5     Sri Lanka       27    2454      91
# 5     6  South Africa       23    2076      90
# 6     7      Pakistan       20    1692      85
# 7     8   West Indies       22    1742      79
# 8     9   Afghanistan        3     170      57
# 9    10    Bangladesh       17     939      55
# 10   11      Zimbabwe        8     144      18
# 11   12       Ireland        0       0       0

# %%
mens_t20 = pd.read_csv("/content/ICC Twenty20 Rankings.csv")
mens_t20
# Out:
#     Pos          Team  Matches  Points  Rating
# 0     1       England       25    6877     275
# 1     2     Australia       22    6047     275
# 2     3         India       35    9319     266
# 3     4      Pakistan       26    6824     262
# 4     5  South Africa       20    5047     252
# ..  ...           ...      ...     ...     ...
# 80   81         China        6       0       0
# 81   82        Turkey        5       0       0
# 82   83     Swaziland        3       0       0
# 83   84        Rwanda        3       0       0
# 84   85       Lesotho        3       0       0
#
# [85 rows x 5 columns]

# %%
womens_odi = pd.read_csv("/content/ICC Women's ODI Team Rankings.csv")
womens_odi
# Out:
#    Pos                Team  Matches  Points  Rating
# 0    1     Australia Women       15    2436     162
# 1    2         India Women       15    1812     121
# 2    3       England Women       14    1670     119
# 3    4  South Africa Women       16    1713     107
# 4    5   New Zealand Women       15    1384      92
# 5    6   West Indies Women       12    1025      85
# 6    7      Pakistan Women       12     927      77
# 7    8    Bangladesh Women        5     306      61
# 8    9     Sri Lanka Women       11     519      47
# 9   10       Ireland Women        2      25      13

# %%
womens_t20 = pd.read_csv("/content/ICC Women's T20 Team Rankings.csv")
womens_t20
# Out:
#     Pos                Team  Matches  Points  Rating
# 0     1     Australia Women       29    8438     291
# 1     2       England Women       30    8405     280
# 2     3         India Women       32    8640     270
# 3     4   New Zealand Women       23    6197     269
# 4     5  South Africa Women       24    5978     249
# 5     6   West Indies Women       26    6126     236
# 6     7      Pakistan Women       24    5516     230
# 7     8     Sri Lanka Women       18    3631     202
# 8     9    Bangladesh Women       26    5001     192
# 9    10       Ireland Women       13    2180     168
# 10   11      Thailand Women       26    4145     159
# 11   12      Zimbabwe Women       11    1711     156
# 12   13      Scotland Women       10    1491     149
# 13   14         Nepal Women       11    1457     132
# 14   15           PNG Women       11    1423     129
# 15   16         Samoa Women        6     749     125
# 16   17           UAE Women       11    1330     121
# ...

# %%
mens_odi.head()
# Out:
#    Pos          Team  Matches  Points  Rating
# 0    1       England       44    5405     123
# 1    2         India       52    6102     117
# 2    3   New Zealand       32    3716     116
# 3    4     Australia       39    4344     111
# 4    5  South Africa       31    3345     108

# %%
womens_odi.head(8)
# Out:
#    Pos                Team  Matches  Points  Rating
# 0    1     Australia Women       15    2436     162
# 1    2         India Women       15    1812     121
# 2    3       England Women       14    1670     119
# 3    4  South Africa Women       16    1713     107
# 4    5   New Zealand Women       15    1384      92
# 5    6   West Indies Women       12    1025      85
# 6    7      Pakistan Women       12     927      77
# 7    8    Bangladesh Women        5     306      61

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (25,10))
sns.barplot('Team', 'Points', data = mens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def trim(x):
  x = x[:3]
  return x

# %%
mens_odi['Team'] = mens_odi['Team'].apply(trim)

# %%
mens_odi
# Out:
#     Pos Team  Matches  Points  Rating
# 0     1  Eng       44    5405     123
# 1     2  Ind       52    6102     117
# 2     3  New       32    3716     116
# 3     4  Aus       39    4344     111
# 4     5  Sou       31    3345     108
# 5     6  Pak       35    3490     100
# 6     7  Ban       34    2989      88
# 7     8  Sri       39    3297      85
# 8     9  Wes       43    3285      76
# 9    10  Afg       28    1549      55
# 10   11  Ire       24    1256      52
# 11   12  Net        5     222      44
# 12   13  Zim       27    1121      42
# 13   14  Oma       12     479      40
# 14   15  Sco       16     419      26
# 15   16  Nep        9     161      18
# 16   17  UAE       15     259      17
# 17   18  Nam        9     152      17
# 18   19  USA       14     185      13
# 19   20  PNG       14       0       0

# %%
mens_test['Team'] = mens_test['Team'].apply(trim)
mens_t20['Team'] = mens_t20['Team'].apply(trim)
womens_odi['Team'] = womens_odi['Team'].apply(trim)
womens_t20['Team'] = womens_t20['Team'].apply(trim)

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Team', 'Points', data = mens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Matches', 'Team', data = mens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mens_odi['Gender'] = "Male"

# %%
mens_odi
# Out:
#     Pos Team  Matches  Points  Rating Gender
# 0     1  Eng       44    5405     123   Male
# 1     2  Ind       52    6102     117   Male
# 2     3  New       32    3716     116   Male
# 3     4  Aus       39    4344     111   Male
# 4     5  Sou       31    3345     108   Male
# 5     6  Pak       35    3490     100   Male
# 6     7  Ban       34    2989      88   Male
# 7     8  Sri       39    3297      85   Male
# 8     9  Wes       43    3285      76   Male
# 9    10  Afg       28    1549      55   Male
# 10   11  Ire       24    1256      52   Male
# 11   12  Net        5     222      44   Male
# 12   13  Zim       27    1121      42   Male
# 13   14  Oma       12     479      40   Male
# 14   15  Sco       16     419      26   Male
# 15   16  Nep        9     161      18   Male
# 16   17  UAE       15     259      17   Male
# 17   18  Nam        9     152      17   Male
# 18   19  USA       14     185      13   Male
# 19   20  PNG       14       0       0   Male

# %%
womens_odi["Gender"] = "Female"
womens_odi
# Out:
#    Pos Team  Matches  Points  Rating  Gender
# 0    1  Aus       15    2436     162  Female
# 1    2  Ind       15    1812     121  Female
# 2    3  Eng       14    1670     119  Female
# 3    4  Sou       16    1713     107  Female
# 4    5  New       15    1384      92  Female
# 5    6  Wes       12    1025      85  Female
# 6    7  Pak       12     927      77  Female
# 7    8  Ban        5     306      61  Female
# 8    9  Sri       11     519      47  Female
# 9   10  Ire        2      25      13  Female

# %%
comb = pd.concat([womens_odi, mens_odi], ignore_index = True)
comb
# Out:
#     Pos Team  Matches  Points  Rating  Gender
# 0     1  Aus       15    2436     162  Female
# 1     2  Ind       15    1812     121  Female
# 2     3  Eng       14    1670     119  Female
# 3     4  Sou       16    1713     107  Female
# 4     5  New       15    1384      92  Female
# 5     6  Wes       12    1025      85  Female
# 6     7  Pak       12     927      77  Female
# 7     8  Ban        5     306      61  Female
# 8     9  Sri       11     519      47  Female
# 9    10  Ire        2      25      13  Female
# 10    1  Eng       44    5405     123    Male
# 11    2  Ind       52    6102     117    Male
# 12    3  New       32    3716     116    Male
# 13    4  Aus       39    4344     111    Male
# 14    5  Sou       31    3345     108    Male
# 15    6  Pak       35    3490     100    Male
# 16    7  Ban       34    2989      88    Male
# 17    8  Sri       39    3297      85    Male
# 18    9  Wes       43    3285      76    Male
# ...

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Team', 'Points', hue = 'Gender' ,data = comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.factorplot('Gender', 'Points', data = comb)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Team', 'Matches', data = mens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Team', 'Rating', data = mens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (15,15))
plt.title("Team vs Matches of Womens_odi", fontsize = 20)
plt.xlabel("Team", fontsize = 15)
plt.ylabel("Matches", fontsize = 15)
sns.barplot('Team', 'Matches', data = womens_odi)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
mens_t20['Gender'] = "Male"

# %%
womens_t20['Gender'] = 'Female'

# %%
comb_t20 = pd.concat([mens_t20, womens_t20], ignore_index= True)
comb_t20
# Out:
#      Pos Team  Matches  Points  Rating  Gender
# 0      1  Eng       25    6877     275    Male
# 1      2  Aus       22    6047     275    Male
# 2      3  Ind       35    9319     266    Male
# 3      4  Pak       26    6824     262    Male
# 4      5  Sou       20    5047     252    Male
# ..   ...  ...      ...     ...     ...     ...
# 136   52  Nor        3       0       0  Female
# 137   53  Les        3       0       0  Female
# 138   54  Fij        6       0       0  Female
# 139   55  Mal        3       0       0  Female
# 140   56  Per        8       0       0  Female
#
# [141 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (60,60))
plt.title("Team vs Points", fontsize = 40)
plt.xlabel("Team", fontsize = 30)
plt.ylabel("Points", fontsize = 30)
sns.barplot('Team', 'Points', hue = 'Gender' ,data = comb_t20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (60,20))
plt.title("Team vs Matches", fontsize = 40)
plt.xlabel("Team", fontsize = 30)
plt.ylabel("Matches", fontsize = 30)
sns.barplot('Team', 'Matches', hue = 'Gender' ,data = comb_t20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, ax = plt.subplots(figsize = (15,15))
sns.barplot('Team', 'Matches', data = mens_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, ax = plt.subplots(figsize = (10,10))


ax=plt.scatter(mens_odi['Team'], mens_odi['Points'])
plt.title("Team vs Points of mens odi", fontsize = 20)
plt.xlabel("Team", fontsize = 15)
plt.ylabel("Points", fontsize = 15)

plt.show()

f, ax = plt.subplots(figsize = (10,10))
ax=sns.scatterplot(data = mens_odi, x = 'Team', y = 'Points')
